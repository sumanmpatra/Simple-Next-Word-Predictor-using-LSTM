# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
with open("dataset.txt","r", encoding="utf-8") as f:
    corpus = f.read().splitlines()

# %%
corpus
# Out:
# ['The sun sets behind the mountains as the sky turns orange.',
#  'I love reading books on rainy evenings with a cup of tea.',
#  'Artificial intelligence is transforming the world rapidly.',
#  'She opened the door and found a letter waiting for her.',
#  'Life is full of surprises and unexpected journeys.',
#  'The cat jumped onto the table and knocked over a glass.',
#  'He dreamed of traveling to distant galaxies someday.',
#  'Music has the power to heal and bring people together.',
#  'Do you know where I left my keys yesterday?',
#  'Once upon a time, there was a brave little girl.',
#  'The train arrived at the station ten minutes late.',
#  'Happiness often comes from the simplest of things.',
#  'The river flowed quietly under the wooden bridge.',
#  'Technology evolves faster than most people can adapt.',
#  'She couldn’t believe her eyes when she saw the results.',
#  'Have you ever wondered why the sky is blue?',
#  'They were walking home when the rain suddenly started.',
#  'A dog barked loudly in the middle of the silent night.',
#  'The world is full of mysteries waiting to be discovered.',
#  'Children love to play games and explore the unknown.',
#  'He worked hard every day to achieve his dreams.',
#  'The stars twinkled brightly in the dark night sky.',
#  'Learning a new language can open doors to new cultures.',
#  'She smiled when she saw her old friends after years.',
#  'The phone rang but nobody answered it.',
#  'Every problem has a solution if you look deep enough.',
#  'The farmer planted seeds and waited for the rain.',
#  'Clouds gathered and a storm began to brew.',
#  'He whispered a secret that nobody else could hear.',
#  'Knowledge is the most valuable treasure one can own.',
#  'The forest was alive with the sounds of birds and insects.',
#  'She walked along the beach collecting seashells.',
#  'Dreams can turn into reality with effort and patience.',
#  'They built a house at the edge of the green valley.',
#  'The clock struck midnight and everything went silent.',
#  'Friendship is one of the strongest bonds in the world.',
#  'The chef cooked a delicious meal for the guests.',
#  'Books are windows into different worlds and ideas.',
#  'He painted the wall with bright colors and patterns.',
#  'The plane flew above the clouds and into the clear sky.',
#  'Sometimes silence speaks louder than words.',
#  'She looked at the old photograph and felt nostalgic.',
#  'Traveling teaches lessons that classrooms never can.',
#  'The fire crackled as they sat around telling stories.',
#  'Success is built on persistence and determination.',
#  'A butterfly landed on the flower gracefully.',
#  'History repeats itself if lessons are forgotten.',
#  'He solved the puzzle after hours of thinking.',
#  'The classroom was filled with laughter and curiosity.',
#  'The city lights sparkled like stars in the distance.',
#  'She kept a diary to remember every small moment of her life.',
#  'The old man told stories of his adventures at sea.',
#  'Time moves slowly when you are waiting for someone.',
#  'The flowers in the garden bloomed after the rain.',
#  'He picked up the guitar and started playing a soft tune.',
#  'The library was quiet except for the sound of turning pages.',
#  'She traveled across countries searching for inspiration.',
#  'The wind howled through the trees on the cold night.',
#  'Happiness is not found, it is created within.',
#  'They laughed together as the movie played on the screen.',
#  'The candle flickered gently in the dark room.',
#  'The teacher explained the lesson with patience and clarity.',
#  'Curiosity is the key to discovering new possibilities.',
#  'He packed his bag and left for a long journey.',
#  'The clouds cleared, and the stars shone brightly.',
#  'They built a campfire and roasted marshmallows together.',
#  'Every artist paints a story with colors and imagination.',
#  'The child asked endless questions about the universe.',
#  'The marketplace was filled with voices and fragrances.',
#  'She danced gracefully as the music filled the hall.',
#  'Wisdom comes from experience and reflection.',
#  'The ocean waves crashed against the rocky shore.',
#  'He smiled politely and held the door open.',
#  'The birds flew south as winter approached.',
#  'Dream big, but work harder to achieve it.',
#  'The magician amazed everyone with his final trick.',
#  'She wore a red scarf on a cold winter day.',
#  'The castle stood tall against the cloudy sky.',
#  'Learning never ends, no matter your age.',
#  'The dog wagged its tail happily when it saw food.',
#  'He opened the window to let fresh air inside.',
#  'The bus stopped at every small town along the way.',
#  'Success requires effort, failure teaches resilience.',
#  'They waved goodbye as the ship left the harbor.',
#  'The detective searched for clues in the dark alley.',
#  'She wrote a poem about love and longing.',
#  'The farmer worked from sunrise to sunset.',
#  'The clock ticked as silence filled the room.',
#  'He painted the sunset with shades of orange and pink.',
#  'The baby laughed when she saw the bubbles.',
#  'The mountain peak was covered in snow.',
#  'She whispered softly so no one else could hear.',
#  'Books hold the wisdom of countless generations.',
#  'The astronaut looked at Earth from space with awe.',
#  'The rain washed away the dust from the streets.',
#  'They planted a tree in memory of their friend.',
#  'The cat slept peacefully near the fireplace.',
#  'Courage means moving forward despite your fears.',
#  'The bakery smelled of fresh bread and pastries.',
#  'She discovered a hidden path in the forest.',
#  'The storm passed, leaving a rainbow behind.',
#  'The child clapped with joy after the performance.',
#  'Memories are treasures that time cannot steal.',
#  'The king declared peace after years of war.',
#  'He carefully folded the paper into an airplane.',
#  'The festival was full of music, food, and laughter.',
#  'Kindness is a language understood by everyone.',
#  'The ship sailed into the horizon as the sun set.',
#  'I am happy today.',
#  'You are my best friend.',
#  'He is working at the office.',
#  'She was reading a book.',
#  'We are going to the park.',
#  'They have a new house.',
#  'It is raining outside.',
#  'This is my favorite place.',
#  'That was a good idea.',
#  'People are waiting for the bus.',
#  'The man is tall.',
#  'The woman is smiling.',
#  'The child is playing with a toy.',
#  'Home is where the heart is.',
#  'The house is small but beautiful.',
#  'School starts in the morning.',
#  'Work makes people busy.',
#  'My friend is coming to visit.',
#  'Love makes life better.',
#  'Life is full of surprises.',
#  'The world is very big.',
#  'Time passes quickly.',
#  'The day is bright and sunny.',
#  'The night is dark and quiet.',
#  'A thing of beauty is a joy forever.',
#  'This place is peaceful.',
#  'I will go to the market.',
#  'You can come with me.',
#  'He did the homework.',
#  'She has a new phone.',
#  'We need more time.',
#  'They want to travel soon.',
#  'It can make a difference.',
#  'That would be nice.',
#  'I know the answer.',
#  'You think too much.',
#  'He says funny things.',
#  'She sees the stars.',
#  'We give our best.',
#  'They take the bus every morning.',
#  'It feels good to rest.',
#  'The big house looks beautiful.',
#  'The small dog is cute.',
#  'Good friends are hard to find.',
#  'Bad habits should be avoided.',
#  'A new day brings new hope.',
#  'The night sky is full of stars.',
#  'People make the world better.',
#  'Work and love make life meaningful.',
#  'Time and place matter in every story.']

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(corpus)
tokenizer.word_index
# Out:
# {'the': 1,
#  'a': 2,
#  'and': 3,
#  'is': 4,
#  'of': 5,
#  'she': 6,
#  'to': 7,
#  'with': 8,
#  'he': 9,
#  'in': 10,
#  'they': 11,
#  'for': 12,
#  'was': 13,
#  'as': 14,
#  'are': 15,
#  'you': 16,
#  'at': 17,
#  'can': 18,
#  'every': 19,
#  'new': 20,
#  'it': 21,
#  'sky': 22,
#  'on': 23,
#  'time': 24,
#  'when': 25,
#  'i': 26,
#  'love': 27,
#  'world': 28,
#  'life': 29,
#  'full': 30,
#  'people': 31,
#  'from': 32,
#  'night': 33,
#  'stars': 34,
#  'after': 35,
#  'that': 36,
#  'into': 37,
#  'waiting': 38,
#  'her': 39,
#  'my': 40,
#  'saw': 41,
#  'rain': 42,
#  'day': 43,
#  'his': 44,
#  'dark': 45,
#  'house': 46,
#  'filled': 47,
#  'small': 48,
#  'books': 49,
#  'music': 50,
#  'has': 51,
#  'together': 52,
#  'left': 53,
#  'dog': 54,
#  'be': 55,
#  'old': 56,
#  'but': 57,
#  'clouds': 58,
#  'one': 59,
#  'built': 60,
#  'child': 61,
#  'big': 62,
#  'work': 63,
#  'bus': 64,
#  'friend': 65,
#  'we': 66,
#  'place': 67,
#  'good': 68,
#  'make': 69,
#  'sun': 70,
#  'behind': 71,
#  'orange': 72,
#  'reading': 73,
#  'opened': 74,
#  'door': 75,
#  'found': 76,
#  'surprises': 77,
#  'cat': 78,
#  'traveling': 79,
#  'know': 80,
#  'where': 81,
#  'happiness': 82,
#  'comes': 83,
#  'things': 84,
#  'than': 85,
#  'most': 86,
#  'have': 87,
#  'home': 88,
#  'started': 89,
#  'silent': 90,
#  'discovered': 91,
#  'worked': 92,
#  'hard': 93,
#  'achieve': 94,
#  'dreams': 95,
#  'brightly': 96,
#  'learning': 97,
#  'language': 98,
#  'open': 99,
#  'smiled': 100,
#  'friends': 101,
#  'years': 102,
#  'phone': 103,
#  'nobody': 104,
#  'if': 105,
#  'farmer': 106,
#  'planted': 107,
#  'storm': 108,
#  'whispered': 109,
#  'else': 110,
#  'could': 111,
#  'hear': 112,
#  'forest': 113,
#  'birds': 114,
#  'along': 115,
#  'effort': 116,
#  'patience': 117,
#  'clock': 118,
#  'painted': 119,
#  'bright': 120,
#  'colors': 121,
#  'flew': 122,
#  'silence': 123,
#  'looked': 124,
#  'teaches': 125,
#  'lessons': 126,
#  'never': 127,
#  'stories': 128,
#  'success': 129,
#  'gracefully': 130,
#  'laughter': 131,
#  'curiosity': 132,
#  'man': 133,
#  'playing': 134,
#  'quiet': 135,
#  'cold': 136,
#  'laughed': 137,
#  'room': 138,
#  'story': 139,
#  'about': 140,
#  'wisdom': 141,
#  'against': 142,
#  'winter': 143,
#  'everyone': 144,
#  'tall': 145,
#  'no': 146,
#  'matter': 147,
#  'your': 148,
#  'food': 149,
#  'fresh': 150,
#  'ship': 151,
#  'sunset': 152,
#  'joy': 153,
#  'best': 154,
#  'this': 155,
#  'beautiful': 156,
#  'morning': 157,
#  'makes': 158,
#  'better': 159,
#  'sets': 160,
#  'mountains': 161,
#  'turns': 162,
#  'rainy': 163,
#  'evenings': 164,
#  'cup': 165,
#  'tea': 166,
#  'artificial': 167,
#  'intelligence': 168,
#  'transforming': 169,
#  'rapidly': 170,
#  'letter': 171,
#  'unexpected': 172,
#  'journeys': 173,
#  'jumped': 174,
#  'onto': 175,
#  'table': 176,
#  'knocked': 177,
#  'over': 178,
#  'glass': 179,
#  'dreamed': 180,
#  'distant': 181,
#  'galaxies': 182,
#  'someday': 183,
#  'power': 184,
#  'heal': 185,
#  'bring': 186,
#  'do': 187,
#  'keys': 188,
#  'yesterday': 189,
#  'once': 190,
#  'upon': 191,
#  'there': 192,
#  'brave': 193,
#  'little': 194,
#  'girl': 195,
#  'train': 196,
#  'arrived': 197,
#  'station': 198,
#  'ten': 199,
#  'minutes': 200,
#  'late': 201,
#  'often': 202,
#  'simplest': 203,
#  'river': 204,
#  'flowed': 205,
#  'quietly': 206,
#  'under': 207,
#  'wooden': 208,
#  'bridge': 209,
#  'technology': 210,
#  'evolves': 211,
#  'faster': 212,
#  'adapt': 213,
#  'couldn’t': 214,
#  'believe': 215,
#  'eyes': 216,
#  'results': 217,
#  'ever': 218,
#  'wondered': 219,
#  'why': 220,
#  'blue': 221,
#  'were': 222,
#  'walking': 223,
#  'suddenly': 224,
#  'barked': 225,
#  'loudly': 226,
#  'middle': 227,
#  'mysteries': 228,
#  'children': 229,
#  'play': 230,
#  'games': 231,
#  'explore': 232,
#  'unknown': 233,
#  'twinkled': 234,
#  'doors': 235,
#  'cultures': 236,
#  'rang': 237,
#  'answered': 238,
#  'problem': 239,
#  'solution': 240,
#  'look': 241,
#  'deep': 242,
#  'enough': 243,
#  'seeds': 244,
#  'waited': 245,
#  'gathered': 246,
#  'began': 247,
#  'brew': 248,
#  'secret': 249,
#  'knowledge': 250,
#  'valuable': 251,
#  'treasure': 252,
#  'own': 253,
#  'alive': 254,
#  'sounds': 255,
#  'insects': 256,
#  'walked': 257,
#  'beach': 258,
#  'collecting': 259,
#  'seashells': 260,
#  'turn': 261,
#  'reality': 262,
#  'edge': 263,
#  'green': 264,
#  'valley': 265,
#  'struck': 266,
#  'midnight': 267,
#  'everything': 268,
#  'went': 269,
#  'friendship': 270,
#  'strongest': 271,
#  'bonds': 272,
#  'chef': 273,
#  'cooked': 274,
#  'delicious': 275,
#  'meal': 276,
#  'guests': 277,
#  'windows': 278,
#  'different': 279,
#  'worlds': 280,
#  'ideas': 281,
#  'wall': 282,
#  'patterns': 283,
#  'plane': 284,
#  'above': 285,
#  'clear': 286,
#  'sometimes': 287,
#  'speaks': 288,
#  'louder': 289,
#  'words': 290,
#  'photograph': 291,
#  'felt': 292,
#  'nostalgic': 293,
#  'classrooms': 294,
#  'fire': 295,
#  'crackled': 296,
#  'sat': 297,
#  'around': 298,
#  'telling': 299,
#  'persistence': 300,
#  'determination': 301,
#  'butterfly': 302,
#  'landed': 303,
#  'flower': 304,
#  'history': 305,
#  'repeats': 306,
#  'itself': 307,
#  'forgotten': 308,
#  'solved': 309,
#  'puzzle': 310,
#  'hours': 311,
#  'thinking': 312,
#  'classroom': 313,
#  'city': 314,
#  'lights': 315,
#  'sparkled': 316,
#  'like': 317,
#  'distance': 318,
#  'kept': 319,
#  'diary': 320,
#  'remember': 321,
#  'moment': 322,
#  'told': 323,
#  'adventures': 324,
#  'sea': 325,
#  'moves': 326,
#  'slowly': 327,
#  'someone': 328,
#  'flowers': 329,
#  'garden': 330,
#  'bloomed': 331,
#  'picked': 332,
#  'up': 333,
#  'guitar': 334,
#  'soft': 335,
#  'tune': 336,
#  'library': 337,
#  'except': 338,
#  'sound': 339,
#  'turning': 340,
#  'pages': 341,
#  'traveled': 342,
#  'across': 343,
#  'countries': 344,
#  'searching': 345,
#  'inspiration': 346,
#  'wind': 347,
#  'howled': 348,
#  'through': 349,
#  'trees': 350,
#  'not': 351,
#  'created': 352,
#  'within': 353,
#  'movie': 354,
#  'played': 355,
#  'screen': 356,
#  'candle': 357,
#  'flickered': 358,
#  'gently': 359,
#  'teacher': 360,
#  'explained': 361,
#  'lesson': 362,
#  'clarity': 363,
#  'key': 364,
#  'discovering': 365,
#  'possibilities': 366,
#  'packed': 367,
#  'bag': 368,
#  'long': 369,
#  'journey': 370,
#  'cleared': 371,
#  'shone': 372,
#  'campfire': 373,
#  'roasted': 374,
#  'marshmallows': 375,
#  'artist': 376,
#  'paints': 377,
#  'imagination': 378,
#  'asked': 379,
#  'endless': 380,
#  'questions': 381,
#  'universe': 382,
#  'marketplace': 383,
#  'voices': 384,
#  'fragrances': 385,
#  'danced': 386,
#  'hall': 387,
#  'experience': 388,
#  'reflection': 389,
#  'ocean': 390,
#  'waves': 391,
#  'crashed': 392,
#  'rocky': 393,
#  'shore': 394,
#  'politely': 395,
#  'held': 396,
#  'south': 397,
#  'approached': 398,
#  'dream': 399,
#  'harder': 400,
#  'magician': 401,
#  'amazed': 402,
#  'final': 403,
#  'trick': 404,
#  'wore': 405,
#  'red': 406,
#  'scarf': 407,
#  'castle': 408,
#  'stood': 409,
#  'cloudy': 410,
#  'ends': 411,
#  'age': 412,
#  'wagged': 413,
#  'its': 414,
#  'tail': 415,
#  'happily': 416,
#  'window': 417,
#  'let': 418,
#  'air': 419,
#  'inside': 420,
#  'stopped': 421,
#  'town': 422,
#  'way': 423,
#  'requires': 424,
#  'failure': 425,
#  'resilience': 426,
#  'waved': 427,
#  'goodbye': 428,
#  'harbor': 429,
#  'detective': 430,
#  'searched': 431,
#  'clues': 432,
#  'alley': 433,
#  'wrote': 434,
#  'poem': 435,
#  'longing': 436,
#  'sunrise': 437,
#  'ticked': 438,
#  'shades': 439,
#  'pink': 440,
#  'baby': 441,
#  'bubbles': 442,
#  'mountain': 443,
#  'peak': 444,
#  'covered': 445,
#  'snow': 446,
#  'softly': 447,
#  'so': 448,
#  'hold': 449,
#  'countless': 450,
#  'generations': 451,
#  'astronaut': 452,
#  'earth': 453,
#  'space': 454,
#  'awe': 455,
#  'washed': 456,
#  'away': 457,
#  'dust': 458,
#  'streets': 459,
#  'tree': 460,
#  'memory': 461,
#  'their': 462,
#  'slept': 463,
#  'peacefully': 464,
#  'near': 465,
#  'fireplace': 466,
#  'courage': 467,
#  'means': 468,
#  'moving': 469,
#  'forward': 470,
#  'despite': 471,
#  'fears': 472,
#  'bakery': 473,
#  'smelled': 474,
#  'bread': 475,
#  'pastries': 476,
#  'hidden': 477,
#  'path': 478,
#  'passed': 479,
#  'leaving': 480,
#  'rainbow': 481,
#  'clapped': 482,
#  'performance': 483,
#  'memories': 484,
#  'treasures': 485,
#  'cannot': 486,
#  'steal': 487,
#  'king': 488,
#  'declared': 489,
#  'peace': 490,
#  'war': 491,
#  'carefully': 492,
#  'folded': 493,
#  'paper': 494,
#  'an': 495,
#  'airplane': 496,
#  'festival': 497,
#  'kindness': 498,
#  'understood': 499,
#  'by': 500,
#  'sailed': 501,
#  'horizon': 502,
#  'set': 503,
#  'am': 504,
#  'happy': 505,
#  'today': 506,
#  'working': 507,
#  'office': 508,
#  'book': 509,
#  'going': 510,
#  'park': 511,
#  'raining': 512,
#  'outside': 513,
#  'favorite': 514,
#  'idea': 515,
#  'woman': 516,
#  'smiling': 517,
#  'toy': 518,
#  'heart': 519,
#  'school': 520,
#  'starts': 521,
#  'busy': 522,
#  'coming': 523,
#  'visit': 524,
#  'very': 525,
#  'passes': 526,
#  'quickly': 527,
#  'sunny': 528,
#  'thing': 529,
#  'beauty': 530,
#  'forever': 531,
#  'peaceful': 532,
#  'will': 533,
#  'go': 534,
#  'market': 535,
#  'come': 536,
#  'me': 537,
#  'did': 538,
#  'homework': 539,
#  'need': 540,
#  'more': 541,
#  'want': 542,
#  'travel': 543,
#  'soon': 544,
#  'difference': 545,
#  'would': 546,
#  'nice': 547,
#  'answer': 548,
#  'think': 549,
#  'too': 550,
#  'much': 551,
#  'says': 552,
#  'funny': 553,
#  'sees': 554,
#  'give': 555,
#  'our': 556,
#  'take': 557,
#  'feels': 558,
#  'rest': 559,
#  'looks': 560,
#  'cute': 561,
#  'find': 562,
#  'bad': 563,
#  'habits': 564,
#  'should': 565,
#  'avoided': 566,
#  'brings': 567,
#  'hope': 568,
#  'meaningful': 569}

# %%
# Converting text to sequences
sequences = tokenizer.texts_to_sequences(corpus)
sequences
# Out:
# [[1, 70, 160, 71, 1, 161, 14, 1, 22, 162, 72],
#  [26, 27, 73, 49, 23, 163, 164, 8, 2, 165, 5, 166],
#  [167, 168, 4, 169, 1, 28, 170],
#  [6, 74, 1, 75, 3, 76, 2, 171, 38, 12, 39],
#  [29, 4, 30, 5, 77, 3, 172, 173],
#  [1, 78, 174, 175, 1, 176, 3, 177, 178, 2, 179],
#  [9, 180, 5, 79, 7, 181, 182, 183],
#  [50, 51, 1, 184, 7, 185, 3, 186, 31, 52],
#  [187, 16, 80, 81, 26, 53, 40, 188, 189],
#  [190, 191, 2, 24, 192, 13, 2, 193, 194, 195],
#  [1, 196, 197, 17, 1, 198, 199, 200, 201],
#  [82, 202, 83, 32, 1, 203, 5, 84],
#  [1, 204, 205, 206, 207, 1, 208, 209],
#  [210, 211, 212, 85, 86, 31, 18, 213],
#  [6, 214, 215, 39, 216, 25, 6, 41, 1, 217],
#  [87, 16, 218, 219, 220, 1, 22, 4, 221],
#  [11, 222, 223, 88, 25, 1, 42, 224, 89],
#  [2, 54, 225, 226, 10, 1, 227, 5, 1, 90, 33],
#  [1, 28, 4, 30, 5, 228, 38, 7, 55, 91],
#  [229, 27, 7, 230, 231, 3, 232, 1, 233],
#  [9, 92, 93, 19, 43, 7, 94, 44, 95],
#  [1, 34, 234, 96, 10, 1, 45, 33, 22],
#  [97, 2, 20, 98, 18, 99, 235, 7, 20, 236],
#  [6, 100, 25, 6, 41, 39, 56, 101, 35, 102],
#  [1, 103, 237, 57, 104, 238, 21],
#  [19, 239, 51, 2, 240, 105, 16, 241, 242, 243],
#  [1, 106, 107, 244, 3, 245, 12, 1, 42],
#  [58, 246, 3, 2, 108, 247, 7, 248],
#  [9, 109, 2, 249, 36, 104, 110, 111, 112],
#  [250, 4, 1, 86, 251, 252, 59, 18, 253],
#  [1, 113, 13, 254, 8, 1, 255, 5, 114, 3, 256],
#  [6, 257, 115, 1, 258, 259, 260],
#  [95, 18, 261, 37, 262, 8, 116, 3, 117],
#  [11, 60, 2, 46, 17, 1, 263, 5, 1, 264, 265],
#  [1, 118, 266, 267, 3, 268, 269, 90],
#  [270, 4, 59, 5, 1, 271, 272, 10, 1, 28],
#  [1, 273, 274, 2, 275, 276, 12, 1, 277],
#  [49, 15, 278, 37, 279, 280, 3, 281],
#  [9, 119, 1, 282, 8, 120, 121, 3, 283],
#  [1, 284, 122, 285, 1, 58, 3, 37, 1, 286, 22],
#  [287, 123, 288, 289, 85, 290],
#  [6, 124, 17, 1, 56, 291, 3, 292, 293],
#  [79, 125, 126, 36, 294, 127, 18],
#  [1, 295, 296, 14, 11, 297, 298, 299, 128],
#  [129, 4, 60, 23, 300, 3, 301],
#  [2, 302, 303, 23, 1, 304, 130],
#  [305, 306, 307, 105, 126, 15, 308],
#  [9, 309, 1, 310, 35, 311, 5, 312],
#  [1, 313, 13, 47, 8, 131, 3, 132],
#  [1, 314, 315, 316, 317, 34, 10, 1, 318],
#  [6, 319, 2, 320, 7, 321, 19, 48, 322, 5, 39, 29],
#  [1, 56, 133, 323, 128, 5, 44, 324, 17, 325],
#  [24, 326, 327, 25, 16, 15, 38, 12, 328],
#  [1, 329, 10, 1, 330, 331, 35, 1, 42],
#  [9, 332, 333, 1, 334, 3, 89, 134, 2, 335, 336],
#  [1, 337, 13, 135, 338, 12, 1, 339, 5, 340, 341],
#  [6, 342, 343, 344, 345, 12, 346],
#  [1, 347, 348, 349, 1, 350, 23, 1, 136, 33],
#  [82, 4, 351, 76, 21, 4, 352, 353],
#  [11, 137, 52, 14, 1, 354, 355, 23, 1, 356],
#  [1, 357, 358, 359, 10, 1, 45, 138],
#  [1, 360, 361, 1, 362, 8, 117, 3, 363],
#  [132, 4, 1, 364, 7, 365, 20, 366],
#  [9, 367, 44, 368, 3, 53, 12, 2, 369, 370],
#  [1, 58, 371, 3, 1, 34, 372, 96],
#  [11, 60, 2, 373, 3, 374, 375, 52],
#  [19, 376, 377, 2, 139, 8, 121, 3, 378],
#  [1, 61, 379, 380, 381, 140, 1, 382],
#  [1, 383, 13, 47, 8, 384, 3, 385],
#  [6, 386, 130, 14, 1, 50, 47, 1, 387],
#  [141, 83, 32, 388, 3, 389],
#  [1, 390, 391, 392, 142, 1, 393, 394],
#  [9, 100, 395, 3, 396, 1, 75, 99],
#  [1, 114, 122, 397, 14, 143, 398],
#  [399, 62, 57, 63, 400, 7, 94, 21],
#  [1, 401, 402, 144, 8, 44, 403, 404],
#  [6, 405, 2, 406, 407, 23, 2, 136, 143, 43],
#  [1, 408, 409, 145, 142, 1, 410, 22],
#  [97, 127, 411, 146, 147, 148, 412],
#  [1, 54, 413, 414, 415, 416, 25, 21, 41, 149],
#  [9, 74, 1, 417, 7, 418, 150, 419, 420],
#  [1, 64, 421, 17, 19, 48, 422, 115, 1, 423],
#  [129, 424, 116, 425, 125, 426],
#  [11, 427, 428, 14, 1, 151, 53, 1, 429],
#  [1, 430, 431, 12, 432, 10, 1, 45, 433],
#  [6, 434, 2, 435, 140, 27, 3, 436],
#  [1, 106, 92, 32, 437, 7, 152],
#  [1, 118, 438, 14, 123, 47, 1, 138],
#  [9, 119, 1, 152, 8, 439, 5, 72, 3, 440],
#  [1, 441, 137, 25, 6, 41, 1, 442],
#  [1, 443, 444, 13, 445, 10, 446],
#  [6, 109, 447, 448, 146, 59, 110, 111, 112],
#  [49, 449, 1, 141, 5, 450, 451],
#  [1, 452, 124, 17, 453, 32, 454, 8, 455],
#  [1, 42, 456, 457, 1, 458, 32, 1, 459],
#  [11, 107, 2, 460, 10, 461, 5, 462, 65],
#  [1, 78, 463, 464, 465, 1, 466],
#  [467, 468, 469, 470, 471, 148, 472],
#  [1, 473, 474, 5, 150, 475, 3, 476],
#  [6, 91, 2, 477, 478, 10, 1, 113],
#  [1, 108, 479, 480, 2, 481, 71],
#  [1, 61, 482, 8, 153, 35, 1, 483],
#  [484, 15, 485, 36, 24, 486, 487],
#  [1, 488, 489, 490, 35, 102, 5, 491],
#  [9, 492, 493, 1, 494, 37, 495, 496],
#  [1, 497, 13, 30, 5, 50, 149, 3, 131],
#  [498, 4, 2, 98, 499, 500, 144],
#  [1, 151, 501, 37, 1, 502, 14, 1, 70, 503],
#  [26, 504, 505, 506],
#  [16, 15, 40, 154, 65],
#  [9, 4, 507, 17, 1, 508],
#  [6, 13, 73, 2, 509],
#  [66, 15, 510, 7, 1, 511],
#  [11, 87, 2, 20, 46],
#  [21, 4, 512, 513],
#  [155, 4, 40, 514, 67],
#  [36, 13, 2, 68, 515],
#  [31, 15, 38, 12, 1, 64],
#  [1, 133, 4, 145],
#  [1, 516, 4, 517],
#  [1, 61, 4, 134, 8, 2, 518],
#  [88, 4, 81, 1, 519, 4],
#  [1, 46, 4, 48, 57, 156],
#  [520, 521, 10, 1, 157],
#  [63, 158, 31, 522],
#  [40, 65, 4, 523, 7, 524],
#  [27, 158, 29, 159],
#  [29, 4, 30, 5, 77],
#  [1, 28, 4, 525, 62],
#  [24, 526, 527],
#  [1, 43, 4, 120, 3, 528],
#  [1, 33, 4, 45, 3, 135],
#  [2, 529, 5, 530, 4, 2, 153, 531],
#  [155, 67, 4, 532],
#  [26, 533, 534, 7, 1, 535],
#  [16, 18, 536, 8, 537],
#  [9, 538, 1, 539],
#  [6, 51, 2, 20, 103],
#  [66, 540, 541, 24],
#  [11, 542, 7, 543, 544],
#  [21, 18, 69, 2, 545],
#  [36, 546, 55, 547],
#  [26, 80, 1, 548],
#  [16, 549, 550, 551],
#  [9, 552, 553, 84],
#  [6, 554, 1, 34],
#  [66, 555, 556, 154],
#  [11, 557, 1, 64, 19, 157],
#  [21, 558, 68, 7, 559],
#  [1, 62, 46, 560, 156],
#  [1, 48, 54, 4, 561],
#  [68, 101, 15, 93, 7, 562],
#  [563, 564, 565, 55, 566],
#  [2, 20, 43, 567, 20, 568],
#  [1, 33, 22, 4, 30, 5, 34],
#  [31, 69, 1, 28, 159],
#  [63, 3, 27, 69, 29, 569],
#  [24, 3, 67, 147, 10, 19, 139]]

# %%
input_sequences = []

for seq in sequences:
    for i in range(1, len(seq)):
        n_gram_seq = seq[:i+1]
        input_sequences.append(n_gram_seq)
input_sequences
# Out:
# [[1, 70],
#  [1, 70, 160],
#  [1, 70, 160, 71],
#  [1, 70, 160, 71, 1],
#  [1, 70, 160, 71, 1, 161],
#  [1, 70, 160, 71, 1, 161, 14],
#  [1, 70, 160, 71, 1, 161, 14, 1],
#  [1, 70, 160, 71, 1, 161, 14, 1, 22],
#  [1, 70, 160, 71, 1, 161, 14, 1, 22, 162],
#  [1, 70, 160, 71, 1, 161, 14, 1, 22, 162, 72],
#  [26, 27],
#  [26, 27, 73],
#  [26, 27, 73, 49],
#  [26, 27, 73, 49, 23],
#  [26, 27, 73, 49, 23, 163],
#  [26, 27, 73, 49, 23, 163, 164],
#  [26, 27, 73, 49, 23, 163, 164, 8],
#  [26, 27, 73, 49, 23, 163, 164, 8, 2],
#  [26, 27, 73, 49, 23, 163, 164, 8, 2, 165],
#  [26, 27, 73, 49, 23, 163, 164, 8, 2, 165, 5],
#  [26, 27, 73, 49, 23, 163, 164, 8, 2, 165, 5, 166],
#  [167, 168],
#  [167, 168, 4],
#  [167, 168, 4, 169],
#  [167, 168, 4, 169, 1],
#  [167, 168, 4, 169, 1, 28],
#  [167, 168, 4, 169, 1, 28, 170],
#  [6, 74],
#  [6, 74, 1],
#  [6, 74, 1, 75],
#  [6, 74, 1, 75, 3],
#  [6, 74, 1, 75, 3, 76],
#  [6, 74, 1, 75, 3, 76, 2],
#  [6, 74, 1, 75, 3, 76, 2, 171],
#  [6, 74, 1, 75, 3, 76, 2, 171, 38],
#  [6, 74, 1, 75, 3, 76, 2, 171, 38, 12],
#  [6, 74, 1, 75, 3, 76, 2, 171, 38, 12, 39],
#  [29, 4],
#  [29, 4, 30],
#  [29, 4, 30, 5],
#  [29, 4, 30, 5, 77],
#  [29, 4, 30, 5, 77, 3],
#  [29, 4, 30, 5, 77, 3, 172],
#  [29, 4, 30, 5, 77, 3, 172, 173],
#  [1, 78],
#  [1, 78, 174],
#  [1, 78, 174, 175],
#  [1, 78, 174, 175, 1],
#  [1, 78, 174, 175, 1, 176],
#  [1, 78, 174, 175, 1, 176, 3],
#  [1, 78, 174, 175, 1, 176, 3, 177],
#  [1, 78, 174, 175, 1, 176, 3, 177, 178],
#  [1, 78, 174, 175, 1, 176, 3, 177, 178, 2],
#  [1, 78, 174, 175, 1, 176, 3, 177, 178, 2, 179],
#  [9, 180],
#  [9, 180, 5],
#  [9, 180, 5, 79],
#  [9, 180, 5, 79, 7],
#  [9, 180, 5, 79, 7, 181],
#  [9, 180, 5, 79, 7, 181, 182],
#  [9, 180, 5, 79, 7, 181, 182, 183],
#  [50, 51],
#  [50, 51, 1],
#  [50, 51, 1, 184],
#  [50, 51, 1, 184, 7],
#  [50, 51, 1, 184, 7, 185],
#  [50, 51, 1, 184, 7, 185, 3],
#  [50, 51, 1, 184, 7, 185, 3, 186],
#  [50, 51, 1, 184, 7, 185, 3, 186, 31],
#  [50, 51, 1, 184, 7, 185, 3, 186, 31, 52],
#  [187, 16],
#  [187, 16, 80],
#  [187, 16, 80, 81],
#  [187, 16, 80, 81, 26],
#  [187, 16, 80, 81, 26, 53],
#  [187, 16, 80, 81, 26, 53, 40],
#  [187, 16, 80, 81, 26, 53, 40, 188],
#  [187, 16, 80, 81, 26, 53, 40, 188, 189],
#  [190, 191],
#  [190, 191, 2],
#  [190, 191, 2, 24],
#  [190, 191, 2, 24, 192],
#  [190, 191, 2, 24, 192, 13],
#  [190, 191, 2, 24, 192, 13, 2],
#  [190, 191, 2, 24, 192, 13, 2, 193],
#  [190, 191, 2, 24, 192, 13, 2, 193, 194],
#  [190, 191, 2, 24, 192, 13, 2, 193, 194, 195],
#  [1, 196],
#  [1, 196, 197],
#  [1, 196, 197, 17],
#  [1, 196, 197, 17, 1],
#  [1, 196, 197, 17, 1, 198],
#  [1, 196, 197, 17, 1, 198, 199],
#  [1, 196, 197, 17, 1, 198, 199, 200],
#  [1, 196, 197, 17, 1, 198, 199, 200, 201],
#  [82, 202],
#  [82, 202, 83],
#  [82, 202, 83, 32],
#  [82, 202, 83, 32, 1],
#  [82, 202, 83, 32, 1, 203],
#  [82, 202, 83, 32, 1, 203, 5],
#  [82, 202, 83, 32, 1, 203, 5, 84],
#  [1, 204],
#  [1, 204, 205],
#  [1, 204, 205, 206],
#  [1, 204, 205, 206, 207],
#  [1, 204, 205, 206, 207, 1],
#  [1, 204, 205, 206, 207, 1, 208],
#  [1, 204, 205, 206, 207, 1, 208, 209],
#  [210, 211],
#  [210, 211, 212],
#  [210, 211, 212, 85],
#  [210, 211, 212, 85, 86],
#  [210, 211, 212, 85, 86, 31],
#  [210, 211, 212, 85, 86, 31, 18],
#  [210, 211, 212, 85, 86, 31, 18, 213],
#  [6, 214],
#  [6, 214, 215],
#  [6, 214, 215, 39],
#  [6, 214, 215, 39, 216],
#  [6, 214, 215, 39, 216, 25],
#  [6, 214, 215, 39, 216, 25, 6],
#  [6, 214, 215, 39, 216, 25, 6, 41],
#  [6, 214, 215, 39, 216, 25, 6, 41, 1],
#  [6, 214, 215, 39, 216, 25, 6, 41, 1, 217],
#  [87, 16],
#  [87, 16, 218],
#  [87, 16, 218, 219],
#  [87, 16, 218, 219, 220],
#  [87, 16, 218, 219, 220, 1],
#  [87, 16, 218, 219, 220, 1, 22],
#  [87, 16, 218, 219, 220, 1, 22, 4],
#  [87, 16, 218, 219, 220, 1, 22, 4, 221],
#  [11, 222],
#  [11, 222, 223],
#  [11, 222, 223, 88],
#  [11, 222, 223, 88, 25],
#  [11, 222, 223, 88, 25, 1],
#  [11, 222, 223, 88, 25, 1, 42],
#  [11, 222, 223, 88, 25, 1, 42, 224],
#  [11, 222, 223, 88, 25, 1, 42, 224, 89],
#  [2, 54],
#  [2, 54, 225],
#  [2, 54, 225, 226],
#  [2, 54, 225, 226, 10],
#  [2, 54, 225, 226, 10, 1],
#  [2, 54, 225, 226, 10, 1, 227],
#  [2, 54, 225, 226, 10, 1, 227, 5],
#  [2, 54, 225, 226, 10, 1, 227, 5, 1],
#  [2, 54, 225, 226, 10, 1, 227, 5, 1, 90],
#  [2, 54, 225, 226, 10, 1, 227, 5, 1, 90, 33],
#  [1, 28],
#  [1, 28, 4],
#  [1, 28, 4, 30],
#  [1, 28, 4, 30, 5],
#  [1, 28, 4, 30, 5, 228],
#  [1, 28, 4, 30, 5, 228, 38],
#  [1, 28, 4, 30, 5, 228, 38, 7],
#  [1, 28, 4, 30, 5, 228, 38, 7, 55],
#  [1, 28, 4, 30, 5, 228, 38, 7, 55, 91],
#  [229, 27],
#  [229, 27, 7],
#  [229, 27, 7, 230],
#  [229, 27, 7, 230, 231],
#  [229, 27, 7, 230, 231, 3],
#  [229, 27, 7, 230, 231, 3, 232],
#  [229, 27, 7, 230, 231, 3, 232, 1],
#  [229, 27, 7, 230, 231, 3, 232, 1, 233],
#  [9, 92],
#  [9, 92, 93],
#  [9, 92, 93, 19],
#  [9, 92, 93, 19, 43],
#  [9, 92, 93, 19, 43, 7],
#  [9, 92, 93, 19, 43, 7, 94],
#  [9, 92, 93, 19, 43, 7, 94, 44],
#  [9, 92, 93, 19, 43, 7, 94, 44, 95],
#  [1, 34],
#  [1, 34, 234],
#  [1, 34, 234, 96],
#  [1, 34, 234, 96, 10],
#  [1, 34, 234, 96, 10, 1],
#  [1, 34, 234, 96, 10, 1, 45],
#  [1, 34, 234, 96, 10, 1, 45, 33],
#  [1, 34, 234, 96, 10, 1, 45, 33, 22],
#  [97, 2],
#  [97, 2, 20],
#  [97, 2, 20, 98],
#  [97, 2, 20, 98, 18],
#  [97, 2, 20, 98, 18, 99],
#  [97, 2, 20, 98, 18, 99, 235],
#  [97, 2, 20, 98, 18, 99, 235, 7],
#  [97, 2, 20, 98, 18, 99, 235, 7, 20],
#  [97, 2, 20, 98, 18, 99, 235, 7, 20, 236],
#  [6, 100],
#  [6, 100, 25],
#  [6, 100, 25, 6],
#  [6, 100, 25, 6, 41],
#  [6, 100, 25, 6, 41, 39],
#  [6, 100, 25, 6, 41, 39, 56],
#  [6, 100, 25, 6, 41, 39, 56, 101],
#  [6, 100, 25, 6, 41, 39, 56, 101, 35],
#  [6, 100, 25, 6, 41, 39, 56, 101, 35, 102],
#  [1, 103],
#  [1, 103, 237],
#  [1, 103, 237, 57],
#  [1, 103, 237, 57, 104],
#  [1, 103, 237, 57, 104, 238],
#  [1, 103, 237, 57, 104, 238, 21],
#  [19, 239],
#  [19, 239, 51],
#  [19, 239, 51, 2],
#  [19, 239, 51, 2, 240],
#  [19, 239, 51, 2, 240, 105],
#  [19, 239, 51, 2, 240, 105, 16],
#  [19, 239, 51, 2, 240, 105, 16, 241],
#  [19, 239, 51, 2, 240, 105, 16, 241, 242],
#  [19, 239, 51, 2, 240, 105, 16, 241, 242, 243],
#  [1, 106],
#  [1, 106, 107],
#  [1, 106, 107, 244],
#  [1, 106, 107, 244, 3],
#  [1, 106, 107, 244, 3, 245],
#  [1, 106, 107, 244, 3, 245, 12],
#  [1, 106, 107, 244, 3, 245, 12, 1],
#  [1, 106, 107, 244, 3, 245, 12, 1, 42],
#  [58, 246],
#  [58, 246, 3],
#  [58, 246, 3, 2],
#  [58, 246, 3, 2, 108],
#  [58, 246, 3, 2, 108, 247],
#  [58, 246, 3, 2, 108, 247, 7],
#  [58, 246, 3, 2, 108, 247, 7, 248],
#  [9, 109],
#  [9, 109, 2],
#  [9, 109, 2, 249],
#  [9, 109, 2, 249, 36],
#  [9, 109, 2, 249, 36, 104],
#  [9, 109, 2, 249, 36, 104, 110],
#  [9, 109, 2, 249, 36, 104, 110, 111],
#  [9, 109, 2, 249, 36, 104, 110, 111, 112],
#  [250, 4],
#  [250, 4, 1],
#  [250, 4, 1, 86],
#  [250, 4, 1, 86, 251],
#  [250, 4, 1, 86, 251, 252],
#  [250, 4, 1, 86, 251, 252, 59],
#  [250, 4, 1, 86, 251, 252, 59, 18],
#  [250, 4, 1, 86, 251, 252, 59, 18, 253],
#  [1, 113],
#  [1, 113, 13],
#  [1, 113, 13, 254],
#  [1, 113, 13, 254, 8],
#  [1, 113, 13, 254, 8, 1],
#  [1, 113, 13, 254, 8, 1, 255],
#  [1, 113, 13, 254, 8, 1, 255, 5],
#  [1, 113, 13, 254, 8, 1, 255, 5, 114],
#  [1, 113, 13, 254, 8, 1, 255, 5, 114, 3],
#  [1, 113, 13, 254, 8, 1, 255, 5, 114, 3, 256],
#  [6, 257],
#  [6, 257, 115],
#  [6, 257, 115, 1],
#  [6, 257, 115, 1, 258],
#  [6, 257, 115, 1, 258, 259],
#  [6, 257, 115, 1, 258, 259, 260],
#  [95, 18],
#  [95, 18, 261],
#  [95, 18, 261, 37],
#  [95, 18, 261, 37, 262],
#  [95, 18, 261, 37, 262, 8],
#  [95, 18, 261, 37, 262, 8, 116],
#  [95, 18, 261, 37, 262, 8, 116, 3],
#  [95, 18, 261, 37, 262, 8, 116, 3, 117],
#  [11, 60],
#  [11, 60, 2],
#  [11, 60, 2, 46],
#  [11, 60, 2, 46, 17],
#  [11, 60, 2, 46, 17, 1],
#  [11, 60, 2, 46, 17, 1, 263],
#  [11, 60, 2, 46, 17, 1, 263, 5],
#  [11, 60, 2, 46, 17, 1, 263, 5, 1],
#  [11, 60, 2, 46, 17, 1, 263, 5, 1, 264],
#  [11, 60, 2, 46, 17, 1, 263, 5, 1, 264, 265],
#  [1, 118],
#  [1, 118, 266],
#  [1, 118, 266, 267],
#  [1, 118, 266, 267, 3],
#  [1, 118, 266, 267, 3, 268],
#  [1, 118, 266, 267, 3, 268, 269],
#  [1, 118, 266, 267, 3, 268, 269, 90],
#  [270, 4],
#  [270, 4, 59],
#  [270, 4, 59, 5],
#  [270, 4, 59, 5, 1],
#  [270, 4, 59, 5, 1, 271],
#  [270, 4, 59, 5, 1, 271, 272],
#  [270, 4, 59, 5, 1, 271, 272, 10],
#  [270, 4, 59, 5, 1, 271, 272, 10, 1],
#  [270, 4, 59, 5, 1, 271, 272, 10, 1, 28],
#  [1, 273],
#  [1, 273, 274],
#  [1, 273, 274, 2],
#  [1, 273, 274, 2, 275],
#  [1, 273, 274, 2, 275, 276],
#  [1, 273, 274, 2, 275, 276, 12],
#  [1, 273, 274, 2, 275, 276, 12, 1],
#  [1, 273, 274, 2, 275, 276, 12, 1, 277],
#  [49, 15],
#  [49, 15, 278],
#  [49, 15, 278, 37],
#  [49, 15, 278, 37, 279],
#  [49, 15, 278, 37, 279, 280],
#  [49, 15, 278, 37, 279, 280, 3],
#  [49, 15, 278, 37, 279, 280, 3, 281],
#  [9, 119],
#  [9, 119, 1],
#  [9, 119, 1, 282],
#  [9, 119, 1, 282, 8],
#  [9, 119, 1, 282, 8, 120],
#  [9, 119, 1, 282, 8, 120, 121],
#  [9, 119, 1, 282, 8, 120, 121, 3],
#  [9, 119, 1, 282, 8, 120, 121, 3, 283],
#  [1, 284],
#  [1, 284, 122],
#  [1, 284, 122, 285],
#  [1, 284, 122, 285, 1],
#  [1, 284, 122, 285, 1, 58],
#  [1, 284, 122, 285, 1, 58, 3],
#  [1, 284, 122, 285, 1, 58, 3, 37],
#  [1, 284, 122, 285, 1, 58, 3, 37, 1],
#  [1, 284, 122, 285, 1, 58, 3, 37, 1, 286],
#  [1, 284, 122, 285, 1, 58, 3, 37, 1, 286, 22],
#  [287, 123],
#  [287, 123, 288],
#  [287, 123, 288, 289],
#  [287, 123, 288, 289, 85],
#  [287, 123, 288, 289, 85, 290],
#  [6, 124],
#  [6, 124, 17],
#  [6, 124, 17, 1],
#  [6, 124, 17, 1, 56],
#  [6, 124, 17, 1, 56, 291],
#  [6, 124, 17, 1, 56, 291, 3],
#  [6, 124, 17, 1, 56, 291, 3, 292],
#  [6, 124, 17, 1, 56, 291, 3, 292, 293],
#  [79, 125],
#  [79, 125, 126],
#  [79, 125, 126, 36],
#  [79, 125, 126, 36, 294],
#  [79, 125, 126, 36, 294, 127],
#  [79, 125, 126, 36, 294, 127, 18],
#  [1, 295],
#  [1, 295, 296],
#  [1, 295, 296, 14],
#  [1, 295, 296, 14, 11],
#  [1, 295, 296, 14, 11, 297],
#  [1, 295, 296, 14, 11, 297, 298],
#  [1, 295, 296, 14, 11, 297, 298, 299],
#  [1, 295, 296, 14, 11, 297, 298, 299, 128],
#  [129, 4],
#  [129, 4, 60],
#  [129, 4, 60, 23],
#  [129, 4, 60, 23, 300],
#  [129, 4, 60, 23, 300, 3],
#  [129, 4, 60, 23, 300, 3, 301],
#  [2, 302],
#  [2, 302, 303],
#  [2, 302, 303, 23],
#  [2, 302, 303, 23, 1],
#  [2, 302, 303, 23, 1, 304],
#  [2, 302, 303, 23, 1, 304, 130],
#  [305, 306],
#  [305, 306, 307],
#  [305, 306, 307, 105],
#  [305, 306, 307, 105, 126],
#  [305, 306, 307, 105, 126, 15],
#  [305, 306, 307, 105, 126, 15, 308],
#  [9, 309],
#  [9, 309, 1],
#  [9, 309, 1, 310],
#  [9, 309, 1, 310, 35],
#  [9, 309, 1, 310, 35, 311],
#  [9, 309, 1, 310, 35, 311, 5],
#  [9, 309, 1, 310, 35, 311, 5, 312],
#  [1, 313],
#  [1, 313, 13],
#  [1, 313, 13, 47],
#  [1, 313, 13, 47, 8],
#  [1, 313, 13, 47, 8, 131],
#  [1, 313, 13, 47, 8, 131, 3],
#  [1, 313, 13, 47, 8, 131, 3, 132],
#  [1, 314],
#  [1, 314, 315],
#  [1, 314, 315, 316],
#  [1, 314, 315, 316, 317],
#  [1, 314, 315, 316, 317, 34],
#  [1, 314, 315, 316, 317, 34, 10],
#  [1, 314, 315, 316, 317, 34, 10, 1],
#  [1, 314, 315, 316, 317, 34, 10, 1, 318],
#  [6, 319],
#  [6, 319, 2],
#  [6, 319, 2, 320],
#  [6, 319, 2, 320, 7],
#  [6, 319, 2, 320, 7, 321],
#  [6, 319, 2, 320, 7, 321, 19],
#  [6, 319, 2, 320, 7, 321, 19, 48],
#  [6, 319, 2, 320, 7, 321, 19, 48, 322],
#  [6, 319, 2, 320, 7, 321, 19, 48, 322, 5],
#  [6, 319, 2, 320, 7, 321, 19, 48, 322, 5, 39],
#  [6, 319, 2, 320, 7, 321, 19, 48, 322, 5, 39, 29],
#  [1, 56],
#  [1, 56, 133],
#  [1, 56, 133, 323],
#  [1, 56, 133, 323, 128],
#  [1, 56, 133, 323, 128, 5],
#  [1, 56, 133, 323, 128, 5, 44],
#  [1, 56, 133, 323, 128, 5, 44, 324],
#  [1, 56, 133, 323, 128, 5, 44, 324, 17],
#  [1, 56, 133, 323, 128, 5, 44, 324, 17, 325],
#  [24, 326],
#  [24, 326, 327],
#  [24, 326, 327, 25],
#  [24, 326, 327, 25, 16],
#  [24, 326, 327, 25, 16, 15],
#  [24, 326, 327, 25, 16, 15, 38],
#  [24, 326, 327, 25, 16, 15, 38, 12],
#  [24, 326, 327, 25, 16, 15, 38, 12, 328],
#  [1, 329],
#  [1, 329, 10],
#  [1, 329, 10, 1],
#  [1, 329, 10, 1, 330],
#  [1, 329, 10, 1, 330, 331],
#  [1, 329, 10, 1, 330, 331, 35],
#  [1, 329, 10, 1, 330, 331, 35, 1],
#  [1, 329, 10, 1, 330, 331, 35, 1, 42],
#  [9, 332],
#  [9, 332, 333],
#  [9, 332, 333, 1],
#  [9, 332, 333, 1, 334],
#  [9, 332, 333, 1, 334, 3],
#  [9, 332, 333, 1, 334, 3, 89],
#  [9, 332, 333, 1, 334, 3, 89, 134],
#  [9, 332, 333, 1, 334, 3, 89, 134, 2],
#  [9, 332, 333, 1, 334, 3, 89, 134, 2, 335],
#  [9, 332, 333, 1, 334, 3, 89, 134, 2, 335, 336],
#  [1, 337],
#  [1, 337, 13],
#  [1, 337, 13, 135],
#  [1, 337, 13, 135, 338],
#  [1, 337, 13, 135, 338, 12],
#  [1, 337, 13, 135, 338, 12, 1],
#  [1, 337, 13, 135, 338, 12, 1, 339],
#  [1, 337, 13, 135, 338, 12, 1, 339, 5],
#  [1, 337, 13, 135, 338, 12, 1, 339, 5, 340],
#  [1, 337, 13, 135, 338, 12, 1, 339, 5, 340, 341],
#  [6, 342],
#  [6, 342, 343],
#  [6, 342, 343, 344],
#  [6, 342, 343, 344, 345],
#  [6, 342, 343, 344, 345, 12],
#  [6, 342, 343, 344, 345, 12, 346],
#  [1, 347],
#  [1, 347, 348],
#  [1, 347, 348, 349],
#  [1, 347, 348, 349, 1],
#  [1, 347, 348, 349, 1, 350],
#  [1, 347, 348, 349, 1, 350, 23],
#  [1, 347, 348, 349, 1, 350, 23, 1],
#  [1, 347, 348, 349, 1, 350, 23, 1, 136],
#  [1, 347, 348, 349, 1, 350, 23, 1, 136, 33],
#  [82, 4],
#  [82, 4, 351],
#  [82, 4, 351, 76],
#  [82, 4, 351, 76, 21],
#  [82, 4, 351, 76, 21, 4],
#  [82, 4, 351, 76, 21, 4, 352],
#  [82, 4, 351, 76, 21, 4, 352, 353],
#  [11, 137],
#  [11, 137, 52],
#  [11, 137, 52, 14],
#  [11, 137, 52, 14, 1],
#  [11, 137, 52, 14, 1, 354],
#  [11, 137, 52, 14, 1, 354, 355],
#  [11, 137, 52, 14, 1, 354, 355, 23],
#  [11, 137, 52, 14, 1, 354, 355, 23, 1],
#  [11, 137, 52, 14, 1, 354, 355, 23, 1, 356],
#  [1, 357],
#  [1, 357, 358],
#  [1, 357, 358, 359],
#  [1, 357, 358, 359, 10],
#  [1, 357, 358, 359, 10, 1],
#  [1, 357, 358, 359, 10, 1, 45],
#  [1, 357, 358, 359, 10, 1, 45, 138],
#  [1, 360],
#  [1, 360, 361],
#  [1, 360, 361, 1],
#  [1, 360, 361, 1, 362],
#  [1, 360, 361, 1, 362, 8],
#  [1, 360, 361, 1, 362, 8, 117],
#  [1, 360, 361, 1, 362, 8, 117, 3],
#  [1, 360, 361, 1, 362, 8, 117, 3, 363],
#  [132, 4],
#  [132, 4, 1],
#  [132, 4, 1, 364],
#  [132, 4, 1, 364, 7],
#  [132, 4, 1, 364, 7, 365],
#  [132, 4, 1, 364, 7, 365, 20],
#  [132, 4, 1, 364, 7, 365, 20, 366],
#  [9, 367],
#  [9, 367, 44],
#  [9, 367, 44, 368],
#  [9, 367, 44, 368, 3],
#  [9, 367, 44, 368, 3, 53],
#  [9, 367, 44, 368, 3, 53, 12],
#  [9, 367, 44, 368, 3, 53, 12, 2],
#  [9, 367, 44, 368, 3, 53, 12, 2, 369],
#  [9, 367, 44, 368, 3, 53, 12, 2, 369, 370],
#  [1, 58],
#  [1, 58, 371],
#  [1, 58, 371, 3],
#  [1, 58, 371, 3, 1],
#  [1, 58, 371, 3, 1, 34],
#  [1, 58, 371, 3, 1, 34, 372],
#  [1, 58, 371, 3, 1, 34, 372, 96],
#  [11, 60],
#  [11, 60, 2],
#  [11, 60, 2, 373],
#  [11, 60, 2, 373, 3],
#  [11, 60, 2, 373, 3, 374],
#  [11, 60, 2, 373, 3, 374, 375],
#  [11, 60, 2, 373, 3, 374, 375, 52],
#  [19, 376],
#  [19, 376, 377],
#  [19, 376, 377, 2],
#  [19, 376, 377, 2, 139],
#  [19, 376, 377, 2, 139, 8],
#  [19, 376, 377, 2, 139, 8, 121],
#  [19, 376, 377, 2, 139, 8, 121, 3],
#  [19, 376, 377, 2, 139, 8, 121, 3, 378],
#  [1, 61],
#  [1, 61, 379],
#  [1, 61, 379, 380],
#  [1, 61, 379, 380, 381],
#  [1, 61, 379, 380, 381, 140],
#  [1, 61, 379, 380, 381, 140, 1],
#  [1, 61, 379, 380, 381, 140, 1, 382],
#  [1, 383],
#  [1, 383, 13],
#  [1, 383, 13, 47],
#  [1, 383, 13, 47, 8],
#  [1, 383, 13, 47, 8, 384],
#  [1, 383, 13, 47, 8, 384, 3],
#  [1, 383, 13, 47, 8, 384, 3, 385],
#  [6, 386],
#  [6, 386, 130],
#  [6, 386, 130, 14],
#  [6, 386, 130, 14, 1],
#  [6, 386, 130, 14, 1, 50],
#  [6, 386, 130, 14, 1, 50, 47],
#  [6, 386, 130, 14, 1, 50, 47, 1],
#  [6, 386, 130, 14, 1, 50, 47, 1, 387],
#  [141, 83],
#  [141, 83, 32],
#  [141, 83, 32, 388],
#  [141, 83, 32, 388, 3],
#  [141, 83, 32, 388, 3, 389],
#  [1, 390],
#  [1, 390, 391],
#  [1, 390, 391, 392],
#  [1, 390, 391, 392, 142],
#  [1, 390, 391, 392, 142, 1],
#  [1, 390, 391, 392, 142, 1, 393],
#  [1, 390, 391, 392, 142, 1, 393, 394],
#  [9, 100],
#  [9, 100, 395],
#  [9, 100, 395, 3],
#  [9, 100, 395, 3, 396],
#  [9, 100, 395, 3, 396, 1],
#  [9, 100, 395, 3, 396, 1, 75],
#  [9, 100, 395, 3, 396, 1, 75, 99],
#  [1, 114],
#  [1, 114, 122],
#  [1, 114, 122, 397],
#  [1, 114, 122, 397, 14],
#  [1, 114, 122, 397, 14, 143],
#  [1, 114, 122, 397, 14, 143, 398],
#  [399, 62],
#  [399, 62, 57],
#  [399, 62, 57, 63],
#  [399, 62, 57, 63, 400],
#  [399, 62, 57, 63, 400, 7],
#  [399, 62, 57, 63, 400, 7, 94],
#  [399, 62, 57, 63, 400, 7, 94, 21],
#  [1, 401],
#  [1, 401, 402],
#  [1, 401, 402, 144],
#  [1, 401, 402, 144, 8],
#  [1, 401, 402, 144, 8, 44],
#  [1, 401, 402, 144, 8, 44, 403],
#  [1, 401, 402, 144, 8, 44, 403, 404],
#  [6, 405],
#  [6, 405, 2],
#  [6, 405, 2, 406],
#  [6, 405, 2, 406, 407],
#  [6, 405, 2, 406, 407, 23],
#  [6, 405, 2, 406, 407, 23, 2],
#  [6, 405, 2, 406, 407, 23, 2, 136],
#  [6, 405, 2, 406, 407, 23, 2, 136, 143],
#  [6, 405, 2, 406, 407, 23, 2, 136, 143, 43],
#  [1, 408],
#  [1, 408, 409],
#  [1, 408, 409, 145],
#  [1, 408, 409, 145, 142],
#  [1, 408, 409, 145, 142, 1],
#  [1, 408, 409, 145, 142, 1, 410],
#  [1, 408, 409, 145, 142, 1, 410, 22],
#  [97, 127],
#  [97, 127, 411],
#  [97, 127, 411, 146],
#  [97, 127, 411, 146, 147],
#  [97, 127, 411, 146, 147, 148],
#  [97, 127, 411, 146, 147, 148, 412],
#  [1, 54],
#  [1, 54, 413],
#  [1, 54, 413, 414],
#  [1, 54, 413, 414, 415],
#  [1, 54, 413, 414, 415, 416],
#  [1, 54, 413, 414, 415, 416, 25],
#  [1, 54, 413, 414, 415, 416, 25, 21],
#  [1, 54, 413, 414, 415, 416, 25, 21, 41],
#  [1, 54, 413, 414, 415, 416, 25, 21, 41, 149],
#  [9, 74],
#  [9, 74, 1],
#  [9, 74, 1, 417],
#  [9, 74, 1, 417, 7],
#  [9, 74, 1, 417, 7, 418],
#  [9, 74, 1, 417, 7, 418, 150],
#  [9, 74, 1, 417, 7, 418, 150, 419],
#  [9, 74, 1, 417, 7, 418, 150, 419, 420],
#  [1, 64],
#  [1, 64, 421],
#  [1, 64, 421, 17],
#  [1, 64, 421, 17, 19],
#  [1, 64, 421, 17, 19, 48],
#  [1, 64, 421, 17, 19, 48, 422],
#  [1, 64, 421, 17, 19, 48, 422, 115],
#  [1, 64, 421, 17, 19, 48, 422, 115, 1],
#  [1, 64, 421, 17, 19, 48, 422, 115, 1, 423],
#  [129, 424],
#  [129, 424, 116],
#  [129, 424, 116, 425],
#  [129, 424, 116, 425, 125],
#  [129, 424, 116, 425, 125, 426],
#  [11, 427],
#  [11, 427, 428],
#  [11, 427, 428, 14],
#  [11, 427, 428, 14, 1],
#  [11, 427, 428, 14, 1, 151],
#  [11, 427, 428, 14, 1, 151, 53],
#  [11, 427, 428, 14, 1, 151, 53, 1],
#  [11, 427, 428, 14, 1, 151, 53, 1, 429],
#  [1, 430],
#  [1, 430, 431],
#  [1, 430, 431, 12],
#  [1, 430, 431, 12, 432],
#  [1, 430, 431, 12, 432, 10],
#  [1, 430, 431, 12, 432, 10, 1],
#  [1, 430, 431, 12, 432, 10, 1, 45],
#  [1, 430, 431, 12, 432, 10, 1, 45, 433],
#  [6, 434],
#  [6, 434, 2],
#  [6, 434, 2, 435],
#  [6, 434, 2, 435, 140],
#  [6, 434, 2, 435, 140, 27],
#  [6, 434, 2, 435, 140, 27, 3],
#  [6, 434, 2, 435, 140, 27, 3, 436],
#  [1, 106],
#  [1, 106, 92],
#  [1, 106, 92, 32],
#  [1, 106, 92, 32, 437],
#  [1, 106, 92, 32, 437, 7],
#  [1, 106, 92, 32, 437, 7, 152],
#  [1, 118],
#  [1, 118, 438],
#  [1, 118, 438, 14],
#  [1, 118, 438, 14, 123],
#  [1, 118, 438, 14, 123, 47],
#  [1, 118, 438, 14, 123, 47, 1],
#  [1, 118, 438, 14, 123, 47, 1, 138],
#  [9, 119],
#  [9, 119, 1],
#  [9, 119, 1, 152],
#  [9, 119, 1, 152, 8],
#  [9, 119, 1, 152, 8, 439],
#  [9, 119, 1, 152, 8, 439, 5],
#  [9, 119, 1, 152, 8, 439, 5, 72],
#  [9, 119, 1, 152, 8, 439, 5, 72, 3],
#  [9, 119, 1, 152, 8, 439, 5, 72, 3, 440],
#  [1, 441],
#  [1, 441, 137],
#  [1, 441, 137, 25],
#  [1, 441, 137, 25, 6],
#  [1, 441, 137, 25, 6, 41],
#  [1, 441, 137, 25, 6, 41, 1],
#  [1, 441, 137, 25, 6, 41, 1, 442],
#  [1, 443],
#  [1, 443, 444],
#  [1, 443, 444, 13],
#  [1, 443, 444, 13, 445],
#  [1, 443, 444, 13, 445, 10],
#  [1, 443, 444, 13, 445, 10, 446],
#  [6, 109],
#  [6, 109, 447],
#  [6, 109, 447, 448],
#  [6, 109, 447, 448, 146],
#  [6, 109, 447, 448, 146, 59],
#  [6, 109, 447, 448, 146, 59, 110],
#  [6, 109, 447, 448, 146, 59, 110, 111],
#  [6, 109, 447, 448, 146, 59, 110, 111, 112],
#  [49, 449],
#  [49, 449, 1],
#  [49, 449, 1, 141],
#  [49, 449, 1, 141, 5],
#  [49, 449, 1, 141, 5, 450],
#  [49, 449, 1, 141, 5, 450, 451],
#  [1, 452],
#  [1, 452, 124],
#  [1, 452, 124, 17],
#  [1, 452, 124, 17, 453],
#  [1, 452, 124, 17, 453, 32],
#  [1, 452, 124, 17, 453, 32, 454],
#  [1, 452, 124, 17, 453, 32, 454, 8],
#  [1, 452, 124, 17, 453, 32, 454, 8, 455],
#  [1, 42],
#  [1, 42, 456],
#  [1, 42, 456, 457],
#  [1, 42, 456, 457, 1],
#  [1, 42, 456, 457, 1, 458],
#  [1, 42, 456, 457, 1, 458, 32],
#  [1, 42, 456, 457, 1, 458, 32, 1],
#  [1, 42, 456, 457, 1, 458, 32, 1, 459],
#  [11, 107],
#  [11, 107, 2],
#  [11, 107, 2, 460],
#  [11, 107, 2, 460, 10],
#  [11, 107, 2, 460, 10, 461],
#  [11, 107, 2, 460, 10, 461, 5],
#  [11, 107, 2, 460, 10, 461, 5, 462],
#  [11, 107, 2, 460, 10, 461, 5, 462, 65],
#  [1, 78],
#  [1, 78, 463],
#  [1, 78, 463, 464],
#  [1, 78, 463, 464, 465],
#  [1, 78, 463, 464, 465, 1],
#  [1, 78, 463, 464, 465, 1, 466],
#  [467, 468],
#  [467, 468, 469],
#  [467, 468, 469, 470],
#  [467, 468, 469, 470, 471],
#  [467, 468, 469, 470, 471, 148],
#  [467, 468, 469, 470, 471, 148, 472],
#  [1, 473],
#  [1, 473, 474],
#  [1, 473, 474, 5],
#  [1, 473, 474, 5, 150],
#  [1, 473, 474, 5, 150, 475],
#  [1, 473, 474, 5, 150, 475, 3],
#  [1, 473, 474, 5, 150, 475, 3, 476],
#  [6, 91],
#  [6, 91, 2],
#  [6, 91, 2, 477],
#  [6, 91, 2, 477, 478],
#  [6, 91, 2, 477, 478, 10],
#  [6, 91, 2, 477, 478, 10, 1],
#  [6, 91, 2, 477, 478, 10, 1, 113],
#  [1, 108],
#  [1, 108, 479],
#  [1, 108, 479, 480],
#  [1, 108, 479, 480, 2],
#  [1, 108, 479, 480, 2, 481],
#  [1, 108, 479, 480, 2, 481, 71],
#  [1, 61],
#  [1, 61, 482],
#  [1, 61, 482, 8],
#  [1, 61, 482, 8, 153],
#  [1, 61, 482, 8, 153, 35],
#  [1, 61, 482, 8, 153, 35, 1],
#  [1, 61, 482, 8, 153, 35, 1, 483],
#  [484, 15],
#  [484, 15, 485],
#  [484, 15, 485, 36],
#  [484, 15, 485, 36, 24],
#  [484, 15, 485, 36, 24, 486],
#  [484, 15, 485, 36, 24, 486, 487],
#  [1, 488],
#  [1, 488, 489],
#  [1, 488, 489, 490],
#  [1, 488, 489, 490, 35],
#  [1, 488, 489, 490, 35, 102],
#  [1, 488, 489, 490, 35, 102, 5],
#  [1, 488, 489, 490, 35, 102, 5, 491],
#  [9, 492],
#  [9, 492, 493],
#  [9, 492, 493, 1],
#  [9, 492, 493, 1, 494],
#  [9, 492, 493, 1, 494, 37],
#  [9, 492, 493, 1, 494, 37, 495],
#  [9, 492, 493, 1, 494, 37, 495, 496],
#  [1, 497],
#  [1, 497, 13],
#  [1, 497, 13, 30],
#  [1, 497, 13, 30, 5],
#  [1, 497, 13, 30, 5, 50],
#  [1, 497, 13, 30, 5, 50, 149],
#  [1, 497, 13, 30, 5, 50, 149, 3],
#  [1, 497, 13, 30, 5, 50, 149, 3, 131],
#  [498, 4],
#  [498, 4, 2],
#  [498, 4, 2, 98],
#  [498, 4, 2, 98, 499],
#  [498, 4, 2, 98, 499, 500],
#  [498, 4, 2, 98, 499, 500, 144],
#  [1, 151],
#  [1, 151, 501],
#  [1, 151, 501, 37],
#  [1, 151, 501, 37, 1],
#  [1, 151, 501, 37, 1, 502],
#  [1, 151, 501, 37, 1, 502, 14],
#  [1, 151, 501, 37, 1, 502, 14, 1],
#  [1, 151, 501, 37, 1, 502, 14, 1, 70],
#  [1, 151, 501, 37, 1, 502, 14, 1, 70, 503],
#  [26, 504],
#  [26, 504, 505],
#  [26, 504, 505, 506],
#  [16, 15],
#  [16, 15, 40],
#  [16, 15, 40, 154],
#  [16, 15, 40, 154, 65],
#  [9, 4],
#  [9, 4, 507],
#  [9, 4, 507, 17],
#  [9, 4, 507, 17, 1],
#  [9, 4, 507, 17, 1, 508],
#  [6, 13],
#  [6, 13, 73],
#  [6, 13, 73, 2],
#  [6, 13, 73, 2, 509],
#  [66, 15],
#  [66, 15, 510],
#  [66, 15, 510, 7],
#  [66, 15, 510, 7, 1],
#  [66, 15, 510, 7, 1, 511],
#  [11, 87],
#  [11, 87, 2],
#  [11, 87, 2, 20],
#  [11, 87, 2, 20, 46],
#  [21, 4],
#  [21, 4, 512],
#  [21, 4, 512, 513],
#  [155, 4],
#  [155, 4, 40],
#  [155, 4, 40, 514],
#  [155, 4, 40, 514, 67],
#  [36, 13],
#  [36, 13, 2],
#  [36, 13, 2, 68],
#  [36, 13, 2, 68, 515],
#  [31, 15],
#  [31, 15, 38],
#  [31, 15, 38, 12],
#  [31, 15, 38, 12, 1],
#  [31, 15, 38, 12, 1, 64],
#  [1, 133],
#  [1, 133, 4],
#  [1, 133, 4, 145],
#  [1, 516],
#  [1, 516, 4],
#  [1, 516, 4, 517],
#  [1, 61],
#  [1, 61, 4],
#  [1, 61, 4, 134],
#  [1, 61, 4, 134, 8],
#  [1, 61, 4, 134, 8, 2],
#  [1, 61, 4, 134, 8, 2, 518],
#  [88, 4],
#  [88, 4, 81],
#  [88, 4, 81, 1],
#  [88, 4, 81, 1, 519],
#  [88, 4, 81, 1, 519, 4],
#  [1, 46],
#  [1, 46, 4],
#  [1, 46, 4, 48],
#  [1, 46, 4, 48, 57],
#  [1, 46, 4, 48, 57, 156],
#  [520, 521],
#  [520, 521, 10],
#  [520, 521, 10, 1],
#  [520, 521, 10, 1, 157],
#  [63, 158],
#  [63, 158, 31],
#  [63, 158, 31, 522],
#  [40, 65],
#  [40, 65, 4],
#  [40, 65, 4, 523],
#  [40, 65, 4, 523, 7],
#  [40, 65, 4, 523, 7, 524],
#  [27, 158],
#  [27, 158, 29],
#  [27, 158, 29, 159],
#  [29, 4],
#  [29, 4, 30],
#  [29, 4, 30, 5],
#  [29, 4, 30, 5, 77],
#  [1, 28],
#  [1, 28, 4],
#  [1, 28, 4, 525],
#  [1, 28, 4, 525, 62],
#  [24, 526],
#  [24, 526, 527],
#  [1, 43],
#  [1, 43, 4],
#  [1, 43, 4, 120],
#  [1, 43, 4, 120, 3],
#  [1, 43, 4, 120, 3, 528],
#  [1, 33],
#  [1, 33, 4],
#  [1, 33, 4, 45],
#  [1, 33, 4, 45, 3],
#  [1, 33, 4, 45, 3, 135],
#  [2, 529],
#  [2, 529, 5],
#  [2, 529, 5, 530],
#  [2, 529, 5, 530, 4],
#  [2, 529, 5, 530, 4, 2],
#  [2, 529, 5, 530, 4, 2, 153],
#  [2, 529, 5, 530, 4, 2, 153, 531],
#  [155, 67],
#  [155, 67, 4],
#  [155, 67, 4, 532],
#  [26, 533],
#  [26, 533, 534],
#  [26, 533, 534, 7],
#  [26, 533, 534, 7, 1],
#  [26, 533, 534, 7, 1, 535],
#  [16, 18],
#  [16, 18, 536],
#  [16, 18, 536, 8],
#  [16, 18, 536, 8, 537],
#  [9, 538],
#  [9, 538, 1],
#  [9, 538, 1, 539],
#  [6, 51],
#  [6, 51, 2],
#  [6, 51, 2, 20],
#  [6, 51, 2, 20, 103],
#  [66, 540],
#  [66, 540, 541],
#  [66, 540, 541, 24],
#  [11, 542],
#  [11, 542, 7],
#  [11, 542, 7, 543],
#  [11, 542, 7, 543, 544],
#  [21, 18],
#  [21, 18, 69],
#  [21, 18, 69, 2],
#  [21, 18, 69, 2, 545],
#  [36, 546],
#  [36, 546, 55],
#  [36, 546, 55, 547],
#  [26, 80],
#  [26, 80, 1],
#  [26, 80, 1, 548],
#  [16, 549],
#  [16, 549, 550],
#  [16, 549, 550, 551],
#  [9, 552],
#  [9, 552, 553],
#  [9, 552, 553, 84],
#  [6, 554],
#  [6, 554, 1],
#  [6, 554, 1, 34],
#  [66, 555],
#  [66, 555, 556],
#  [66, 555, 556, 154],
#  [11, 557],
#  [11, 557, 1],
#  [11, 557, 1, 64],
#  [11, 557, 1, 64, 19],
#  [11, 557, 1, 64, 19, 157],
#  [21, 558],
#  [21, 558, 68],
#  [21, 558, 68, 7],
#  [21, 558, 68, 7, 559],
#  [1, 62],
#  [1, 62, 46],
#  [1, 62, 46, 560],
#  [1, 62, 46, 560, 156],
#  [1, 48],
#  [1, 48, 54],
#  [1, 48, 54, 4],
#  [1, 48, 54, 4, 561],
#  ...]

# %%
# Pad all sequences to the same length
max_seq_len = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre')

# %%
# Split predictors (X) and label (y)
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# %%
vocab_size = len(tokenizer.word_index) + 1

# %%
# Convert y to categorical (one-hot encoding)
from keras.utils import to_categorical
y = to_categorical(y, num_classes=vocab_size)

# %%
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (1035, 11)
# Shape of y: (1035, 570)

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense

model = Sequential()
model.add(Embedding(vocab_size, 50, input_shape=(max_seq_len-1,)))
model.add(LSTM(150))
model.add(Dense(vocab_size, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 11, 50)         │        28,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 150)            │       120,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 570)            │        86,070 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 235,170 (918.63 KB)
#  Trainable params: 235,170 (918.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1913 - loss: 3.8297
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1981 - loss: 3.7020
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2261 - loss: 3.5655
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2454 - loss: 3.4390
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2773 - loss: 3.3277
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2986 - loss: 3.2138
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3256 - loss: 3.0957
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3459 - loss: 2.9877
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3643 - loss: 2.8823
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4116 - loss: 2.7773
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4406 - loss: 2.6857
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4812 - loss: 2.5815
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4937 - loss: 2.4964
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5130 - loss: 2.4051
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5333 - loss: 2.3125
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5594 - loss: 2.2304
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5816 - loss: 2.1513
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6000 - loss: 2.0703
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6203 - loss: 1.9963
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6396 - loss: 1.9257
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6589 - loss: 1.8536
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6792 - loss: 1.7856
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6928 - loss: 1.7194
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6928 - loss: 1.6603
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7111 - loss: 1.5998
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7285 - loss: 1.5456
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7362 - loss: 1.4936
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7459 - loss: 1.4405
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7643 - loss: 1.3919
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7768 - loss: 1.3430
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7855 - loss: 1.2931
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7942 - loss: 1.2524
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7961 - loss: 1.2110
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8048 - loss: 1.1718
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8087 - loss: 1.1331
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8126 - loss: 1.0987
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8251 - loss: 1.0647
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8271 - loss: 1.0317
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8357 - loss: 1.0014
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8435 - loss: 0.9686
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8444 - loss: 0.9404
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8454 - loss: 0.9142
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8541 - loss: 0.8895
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8522 - loss: 0.8652
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8580 - loss: 0.8453
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8647 - loss: 0.8221
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8599 - loss: 0.7973
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8638 - loss: 0.7795
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8705 - loss: 0.7584
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8705 - loss: 0.7409
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8696 - loss: 0.7226
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8696 - loss: 0.7077
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8725 - loss: 0.6923
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8725 - loss: 0.6783
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8715 - loss: 0.6628
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8744 - loss: 0.6499
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8754 - loss: 0.6386
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8763 - loss: 0.6256
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8773 - loss: 0.6147
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8783 - loss: 0.6034
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8773 - loss: 0.5939
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8792 - loss: 0.5837
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8773 - loss: 0.5733
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8754 - loss: 0.5680
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8783 - loss: 0.5568
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8773 - loss: 0.5486
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8715 - loss: 0.5407
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8792 - loss: 0.5331
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8812 - loss: 0.5282
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8783 - loss: 0.5197
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8783 - loss: 0.5138
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8792 - loss: 0.5061
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8783 - loss: 0.5006
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8754 - loss: 0.4967
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8783 - loss: 0.4924
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8783 - loss: 0.4850
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8734 - loss: 0.4812
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8821 - loss: 0.4768
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8792 - loss: 0.4710
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8812 - loss: 0.4656
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8763 - loss: 0.4636
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8773 - loss: 0.4597
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8812 - loss: 0.4549
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8744 - loss: 0.4518
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8812 - loss: 0.4532
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8792 - loss: 0.4462
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8763 - loss: 0.4450
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8821 - loss: 0.4395
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8744 - loss: 0.4380
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8831 - loss: 0.4353
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8821 - loss: 0.4312
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8763 - loss: 0.4292
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8812 - loss: 0.4263
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8773 - loss: 0.4253
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8783 - loss: 0.4238
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8773 - loss: 0.4211
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8783 - loss: 0.4171
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8792 - loss: 0.4175
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8783 - loss: 0.4160
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8792 - loss: 0.4147

# %%
import numpy as np
text1 = "The mountain"

for i in range(10):
    token_text = tokenizer.texts_to_sequences([text1])[0]

    padded_token_text = pad_sequences([token_text], maxlen=vocab_size,padding='pre')

    pos= np.argmax(model.predict(padded_token_text))

    for word, index in tokenizer.word_index.items():
        if index==pos:
            text1 = text1 + " " + word
            print(text1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# The mountain peak
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# The mountain peak was
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# The mountain peak was is
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# The mountain peak was is smiling
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# The mountain peak was is smiling but
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# The mountain peak was is smiling but tall
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# The mountain peak was is smiling but tall against
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# The mountain peak was is smiling but tall against the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# The mountain peak was is smiling but tall against the lesson
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# The mountain peak was is smiling but tall against the lesson with

# %%
text2 = "He smiled politely"

for i in range(6):
    token_text = tokenizer.texts_to_sequences([text2])[0]

    padded_token_text = pad_sequences([token_text], maxlen=vocab_size,padding='pre')

    pos= np.argmax(model.predict(padded_token_text))

    for word, index in tokenizer.word_index.items():
        if index==pos:
            text2 = text2 + " " + word
            print(text2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# He smiled politely and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# He smiled politely and traveling
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# He smiled politely and traveling to
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# He smiled politely and traveling to visit
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# He smiled politely and traveling to visit to
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# He smiled politely and traveling to visit to find

# %%
text3 = "the dog"
for i in range(3):
    token_text = tokenizer.texts_to_sequences([text3])[0]

    padded_token_text = pad_sequences([token_text], maxlen=vocab_size,padding='pre')

    pos= np.argmax(model.predict(padded_token_text))

    for word, index in tokenizer.word_index.items():
        if index==pos:
            text3 = text3 + " " + word
            print(text3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# the dog wagged
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# the dog wagged its
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# the dog wagged its tail

# %%
text4 = "A butterfly"
for i in range(8):
    token_text = tokenizer.texts_to_sequences([text4])[0]

    padded_token_text = pad_sequences([token_text], maxlen=vocab_size,padding='pre')

    pos= np.argmax(model.predict(padded_token_text))

    for word, index in tokenizer.word_index.items():
        if index==pos:
            text4 = text4 + " " + word
            print(text4)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# A butterfly landed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# A butterfly landed a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# A butterfly landed a house
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# A butterfly landed a house at
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# A butterfly landed a house at the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# A butterfly landed a house at the bus
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# A butterfly landed a house at the bus every
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# A butterfly landed a house at the bus every morning
